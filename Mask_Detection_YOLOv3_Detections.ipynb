# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/yolov3/dataset.zip"

# %%
with open('/content/predict.txt') as f:
  TEST_IMAGES = f.read().splitlines()

# %%
TEST_IMAGES
# Out:
# ['dataset/images/crowd_mask66.jpg',
#  'dataset/images/new_201.jpg',
#  'dataset/images/194.jpg',
#  'dataset/images/asian_mask37.jpg',
#  'dataset/images/crowd_mask101.jpg',
#  'dataset/images/new_57.jpg',
#  'dataset/images/new_105.jpg',
#  'dataset/images/24.jpg',
#  'dataset/images/asian_mask289.jpg',
#  'dataset/images/new_145.jpg',
#  'dataset/images/167.jpg',
#  'dataset/images/109.jpg',
#  'dataset/images/asian_mask174.jpg',
#  'dataset/images/crowd_mask19.jpg',
#  'dataset/images/new_114.jpg',
#  'dataset/images/60.jpg',
#  'dataset/images/asian_mask224.jpg',
#  'dataset/images/asian_mask142.jpg',
#  'dataset/images/74.jpg',
#  'dataset/images/72.jpg',
#  'dataset/images/asian_mask103.jpg',
#  'dataset/images/new_48.jpg',
#  'dataset/images/new_245.jpg',
#  'dataset/images/asian_mask128.jpg',
#  'dataset/images/44.jpg',
#  'dataset/images/157.jpg',
#  'dataset/images/new_130.jpg',
#  'dataset/images/new_50.jpg',
#  'dataset/images/asian_mask298.jpg',
#  'dataset/images/new_255.jpg',
#  'dataset/images/117.jpg',
#  'dataset/images/asian_mask222.jpg',
#  'dataset/images/asian_mask75.jpg',
#  'dataset/images/new_232.jpg',
#  'dataset/images/new_188.jpg',
#  'dataset/images/new_161.jpg',
#  'dataset/images/new_49.jpg',
#  'dataset/images/new_134.jpg',
#  'dataset/images/new_47.jpg',
#  'dataset/images/asian_mask203.jpg',
#  'dataset/images/asian_mask114.jpg',
#  'dataset/images/asian_mask79.jpg',
#  'dataset/images/asian_mask27.jpg',
#  'dataset/images/asian_mask140.jpg',
#  'dataset/images/asian_mask91.jpg',
#  'dataset/images/new_139.jpg',
#  'dataset/images/crowd_mask69.jpg',
#  'dataset/images/new_26.jpg',
#  'dataset/images/asian_mask59.jpg',
#  'dataset/images/new_51.jpg',
#  'dataset/images/20.jpg',
#  'dataset/images/asian_mask40.jpg',
#  'dataset/images/asian_mask196.jpg',
#  'dataset/images/asian_mask144.jpg',
#  'dataset/images/76.jpg',
#  'dataset/images/asian_mask221.jpg',
#  'dataset/images/new_106.jpg',
#  'dataset/images/crowd_mask74.jpg',
#  'dataset/images/63.jpg',
#  'dataset/images/asian_mask210.jpg',
#  'dataset/images/68.jpg',
#  'dataset/images/new_52.jpg',
#  'dataset/images/new_158.jpg',
#  'dataset/images/new_233.jpg',
#  'dataset/images/153.jpg',
#  'dataset/images/crowd_mask42.jpg',
#  'dataset/images/65.jpg',
#  'dataset/images/asian_mask161.jpg',
#  'dataset/images/new_149.jpg',
#  'dataset/images/crowd_mask158.jpg',
#  'dataset/images/asian_mask176.jpg',
#  'dataset/images/new_151.jpg',
#  'dataset/images/new_182.jpg',
#  'dataset/images/67.jpg',
#  'dataset/images/new_169.jpg',
#  'dataset/images/asian_mask138.jpg']

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Load the Model
net = cv2.dnn.readNet('/content/drive/MyDrive/yolov3/yolov3_training_last.weights','/content/yolov3_test.cfg')

# Loading the Classes
classes = []
with open('/content/classes.names', 'r') as f:
    classes = f.read().splitlines()

# %%
classes
# Out:
# ['Mask', 'Without_mask']

# %%
def detect(image):
  # Loading the Image
  img = cv2.imread(image)
  height, width, _ = img.shape

  # Creating Blob of Image to Feed to Network
  blob = cv2.dnn.blobFromImage(img, 1/255, (416, 416), (0,0,0), swapRB=True, crop=False)

  # After Normalization
  # Input to model
  net.setInput(blob)

  # To Make Detections and get bounded boxes and get classes names
  output_layers_names = net.getUnconnectedOutLayersNames()
  layerOutputs = net.forward(output_layers_names)

  # Extract the bounding boxes
  boxes = []
  confidences = []
  class_ids = []
  for output in layerOutputs:
      for detection in output:
          # To get highest score of class
          scores = detection[5:]
          class_id = np.argmax(scores)
          confidence = scores[class_id]
          if confidence > 0.5:
              center_x = int(detection[0]*width)
              center_y = int(detection[1]*height)
              w = int(detection[2]*width)
              h = int(detection[3]*height)

              # To get Upper corners of bounding boxes
              x = int(center_x - w/2)
              y = int(center_y - h/2)

              boxes.append([x, y, w, h])
              confidences.append((float(confidence)))
              class_ids.append(class_id)


  # in the case if we have more than bounding boxes for a single object then we want to select bounding box having highest confidence using this function
  indexes = cv2.dnn.NMSBoxes(boxes, confidences, .5, .4)

  font = cv2.FONT_HERSHEY_PLAIN
  # To get random color values to make more beautiful
  colors = np.random.uniform(0, 255, size=(len(boxes), 3))

  if len(indexes) > 0:
      # iterate over all boxes found
      for i in indexes.flatten():
          # getting postion of bounding boxes
          x, y, w, h = boxes[i]
          # get label name from classes
          label = str(classes[class_ids[i]])
          # getting confidence value
          confidence = str(round(confidences[i], 2))
          # assigning color
          color = colors[i]
          #creating bounding box
          cv2.rectangle(img, (x,y), (x+w, y+h), color, 2)
          cv2.rectangle(img, (x, y-40), (x+w, y-2), color, -1)
          #Displaying label class name
          cv2.putText(img, label.capitalize(), (x+4, y-10), font, 1.1, (255, 255, 255), 2)

  cv2_imshow(img)

  # for b in blob:
  #     for n, img_blob in enumerate(b):
  #         cv2.imshow(str(n), img_blob)

# %%
import random
for _ in range(10):
  detect(random.choice(TEST_IMAGES))

# %%
detect("/content/iasfa.jpeg")
# Out:
# <PIL.Image.Image image mode=RGB size=700x394 at 0x7F8AB809E710>

# %%
detect('/content/GettyImages-1239699427.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1200x600 at 0x7F8AB809E750>
